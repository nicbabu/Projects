# %%
import pandas as pd
data = pd.read_csv(r'D:\Pycharm_Projects\Projects\pythonProject\Data_Kaggle\2026 QS World University Rankings.csv')
data.head() # It shows the top 5 rows from the datasets
# Out:
#   2026 Rank Previous Rank                             Institution Name  \
# 0         1             1  Massachusetts Institute of Technology (MIT)
# 1         2             2                      Imperial College London
# 2         3             6                          Stanford University
# 3         4             3                         University of Oxford
# 4         5             4                           Harvard University
#
#           Country/Territory    Region Size Focus Research  \
# 0  United States of America  Americas    M    CO       VH
# 1            United Kingdom    Europe    L    FO       VH
# 2  United States of America  Americas    L    FC       VH
# 3            United Kingdom    Europe    L    FC       VH
# 4  United States of America  Americas    L    FC       VH
#
#                    Status  AR SCORE  ... ISR RANK  ISD SCORE ISD RANK  \
# 0  Private not for Profit     100.0  ...      153       92.3      130
# ...

# %%
#It shows the bottom 5 rows from the dataset's
data.tail()
# Out:
#      2026 Rank Previous Rank            Institution Name   Country/Territory  \
# 1496     1401+     1201-1400  University of West Bohemia             Czechia
# 1497     1401+     1201-1400   Voronezh State University  Russian Federation
# 1498     1401+           NaN         Walailak University            Thailand
# 1499     1401+     1201-1400        Yamaguchi University               Japan
# 1500     1401+     1201-1400         Youngsan University   Republic of Korea
#
#       Region Size Focus Research              Status  AR SCORE  ... ISR RANK  \
# 1496  Europe    M    CO       VH              Public       7.2  ...     801+
# 1497  Europe    L    CO       HI              Public       5.7  ...      546
# 1498    Asia    L    FC       MD              Public       8.3  ...     801+
# 1499    Asia    M    FC       HI              Public       4.4  ...     801+
# 1500    Asia    M    SP       MD  Private for Profit       6.5  ...      658
#
# ...

# %%
data.shape # It shows the rows and columns in the datasets
# Out:
# (1501, 30)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501 entries, 0 to 1500
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   2026 Rank          1501 non-null   object
#  1   Previous Rank      1389 non-null   object
#  2   Institution Name   1501 non-null   object
#  3   Country/Territory  1501 non-null   object
#  4   Region             1501 non-null   object
#  5   Size               1500 non-null   object
#  6   Focus              1501 non-null   object
#  7   Research           1500 non-null   object
#  8   Status             1454 non-null   object
#  9   AR SCORE           1501 non-null   float64
#  10  AR RANK            1501 non-null   object
#  11  ER SCORE           1501 non-null   float64
#  12  ER RANK            1501 non-null   object
#  13  FSR SCORE          1501 non-null   float64
#  14  FSR RANK           1501 non-null   object
#  15  CPF SCORE          1501 non-null   float64
# ...

# %%
data.describe()# It is used to give the total statistics of the data sets for each rows and columns
# Out:
#           AR SCORE     ER SCORE    FSR SCORE    CPF SCORE    IFR SCORE  \
# count  1501.000000  1501.000000  1501.000000  1501.000000  1414.000000
# mean     25.785943    26.944237    33.950433    30.425516    36.305658
# std      24.500905    25.504494    28.440071    29.679882    35.252024
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       8.800000     8.500000    10.800000     6.000000     6.600000
# 50%      16.000000    16.500000    23.500000    18.000000    20.100000
# 75%      32.700000    37.500000    50.500000    49.700000    66.100000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#         ISR SCORE    ISD SCORE    IRN SCORE     EO SCORE    SUS SCORE
# count  1464.00000  1464.000000  1499.000000  1501.000000  1477.000000
# mean     33.32541    34.526981    53.356905    29.989674    51.254367
# std      32.75066    31.108600    28.920632    29.197573    21.266331
# ...

# %%
data.isnull().sum() # for finding the null value in the data and sum of the null value
# Out:
# 2026 Rank              0
# Previous Rank        112
# Institution Name       0
# Country/Territory      0
# Region                 0
# Size                   1
# Focus                  0
# Research               1
# Status                47
# AR SCORE               0
# AR RANK                0
# ER SCORE               0
# ER RANK                0
# FSR SCORE              0
# FSR RANK               0
# CPF SCORE              0
# CPF RANK               0
# IFR SCORE             87
# IFR RANK              87
# ISR SCORE             37
# ISR RANK              37
# ISD SCORE             37
# ISD RANK              37
# IRN SCORE              2
# IRN RANK               2
# EO SCORE               0
# EO RANK                0
# SUS SCORE             24
# SUS RANK              24
# Overall SCORE          0
# dtype: int64

# %%
data['Previous Rank']= data['Previous Rank'].fillna('Unranked')
data
data.columns
# Out:
# Index(['2026 Rank', 'Previous Rank', 'Institution Name', 'Country/Territory',
#        'Region', 'Size', 'Focus', 'Research', 'Status', 'AR SCORE', 'AR RANK',
#        'ER SCORE', 'ER RANK', 'FSR SCORE', 'FSR RANK', 'CPF SCORE', 'CPF RANK',
#        'IFR SCORE', 'IFR RANK', 'ISR SCORE', 'ISR RANK', 'ISD SCORE',
#        'ISD RANK', 'IRN SCORE', 'IRN RANK', 'EO SCORE', 'EO RANK', 'SUS SCORE',
#        'SUS RANK', 'Overall SCORE'],
#       dtype='object')

# %%
print((data.isnull().sum() / len(data)) * 100) # checking the percentage of null value
# Out:
# 2026 Rank            0.000000
# Previous Rank        0.000000
# Institution Name     0.000000
# Country/Territory    0.000000
# Region               0.000000
# Size                 0.066622
# Focus                0.000000
# Research             0.066622
# Status               3.131246
# AR SCORE             0.000000
# AR RANK              0.000000
# ER SCORE             0.000000
# ER RANK              0.000000
# FSR SCORE            0.000000
# FSR RANK             0.000000
# CPF SCORE            0.000000
# CPF RANK             0.000000
# IFR SCORE            5.796136
# IFR RANK             5.796136
# ISR SCORE            2.465023
# ISR RANK             2.465023
# ISD SCORE            2.465023
# ISD RANK             2.465023
# IRN SCORE            0.133245
# IRN RANK             0.133245
# EO SCORE             0.000000
# EO RANK              0.000000
# SUS SCORE            1.598934
# SUS RANK             1.598934
# Overall SCORE        0.000000
# dtype: float64

# %%
filtered_data = data[(data['Country/Territory'] == 'United States of America') & (data['Region'] == 'Americas')]
print(filtered_data['Institution Name'])
filtered_data.shape
# Out:
# 0        Massachusetts Institute of Technology (MIT)
# 2                                Stanford University
# 4                                 Harvard University
# 9       California Institute of Technology (Caltech)
# 12                             University of Chicago
#                             ...
# 1419                      Cleveland State University
# 1452                  San Francisco State University
# 1489                    University of Hawaii at Hilo
# 1490              University of Missouri Saint Louis
# 1494                       University of the Pacific
# Name: Institution Name, Length: 192, dtype: object
# (192, 30)

# %%
data['Status']= data['Status'].fillna('Unknown')
data['SUS SCORE']=data['SUS SCORE'].ffill()
data
# Out:
#      2026 Rank Previous Rank                             Institution Name  \
# 0            1             1  Massachusetts Institute of Technology (MIT)
# 1            2             2                      Imperial College London
# 2            3             6                          Stanford University
# 3            4             3                         University of Oxford
# 4            5             4                           Harvard University
# ...        ...           ...                                          ...
# 1496     1401+     1201-1400                   University of West Bohemia
# 1497     1401+     1201-1400                    Voronezh State University
# 1498     1401+      Unranked                          Walailak University
# 1499     1401+     1201-1400                         Yamaguchi University
# 1500     1401+     1201-1400                          Youngsan University
#
#              Country/Territory    Region Focus Research  \
# ...

# %%
data =data. drop(['Size', 'AR RANK','ER RANK', 'FSR SCORE', 'FSR RANK', 'CPF RANK',
       'IFR SCORE', 'IFR RANK', 'ISR SCORE', 'ISR RANK', 'ISD SCORE',
       'ISD RANK', 'IRN SCORE', 'IRN RANK', 'EO SCORE', 'EO RANK',
       'SUS RANK'], axis=1, errors='ignore') # this is less likely important
data
# Out:
#      2026 Rank Previous Rank                             Institution Name  \
# 0            1             1  Massachusetts Institute of Technology (MIT)
# 1            2             2                      Imperial College London
# 2            3             6                          Stanford University
# 3            4             3                         University of Oxford
# 4            5             4                           Harvard University
# ...        ...           ...                                          ...
# 1496     1401+     1201-1400                   University of West Bohemia
# 1497     1401+     1201-1400                    Voronezh State University
# 1498     1401+      Unranked                          Walailak University
# 1499     1401+     1201-1400                         Yamaguchi University
# 1500     1401+     1201-1400                          Youngsan University
#
#              Country/Territory    Region Focus Research  \
# ...

# %%
#finding the first top 10 university to check its previous rank
import matplotlib.pyplot as plt
import numpy as np
data['2026 Rank(cleaned)']= data['2026 Rank'].astype(str).str.extract(r'(\d+)').astype(float) # it is used to clean the rank columns as it converts to numeric by extracting the first number
data['Previous Rank(cleaned)']= data['Previous Rank'].astype(str).str.extract(r'(\d+)').astype(float)  # it is used to clean the rank columns as it converts to numeric by extracting the first number
top_10_universities = data.sort_values('2026 Rank(cleaned)').head(10)
print(top_universities[['Institution Name', '2026 Rank', 'Previous Rank']])
# Out:
#                                     Institution Name 2026 Rank Previous Rank
# 0        Massachusetts Institute of Technology (MIT)         1             1
# 1                            Imperial College London         2             2
# 2                                Stanford University         3             6
# 3                               University of Oxford         4             3
# 4                                 Harvard University         5             4
# 5                            University of Cambridge         6             5
# 6  ETH Zurich (Swiss Federal Institute of Technol...         7             7
# 7             National University of Singapore (NUS)         8             8
# 8                    UCL (University College London)         9             9
# 9       California Institute of Technology (Caltech)        10            10

# %%
#Plot a simple line chart for rank movement
plt.figure(figsize=(10,6))

for i, row in top_10_universities.iterrows():
    plt.plot([0, 1], [row['Previous Clean'], row['2026 Clean']], marker='o')  # line from previous to 2026
    plt.text(0, row['Previous Clean'], row['Institution Name'], ha='right', fontsize=8)  # label on left
plt.xticks([0, 1], ['Previous Rank', '2026 Rank'])
plt.title('Top 10 Universities: Rank Change')
plt.gca().invert_yaxis()  
plt.grid(True)
plt.show()

# %%
# plotting top 10 2026 rank university
top10 = data.sort_values('2026 Clean').head(10)

plt.figure(figsize=(10, 6))
plt.barh(top_10_universities['Institution Name'], top10['2026 Clean'], color='Orange')
plt.xlabel('2026 Rank')
plt.title('Top 10 Universities by 2026 Rank')
plt.gca().invert_yaxis()  #It makes rank 1 at the top
plt.show()

# %%
top_10_universities = data.sort_values('2026 Rank(cleaned)').head(10)
scores = top_10_universities[['Institution Name', 'AR SCORE', 'CPF SCORE']]
print(scores)

correlation = scores[['AR SCORE', 'CPF SCORE']].corr()
print("Correlation between AR SCORE and CPF SCORE:")
print(correlation)
# Out:
#                                     Institution Name  AR SCORE  CPF SCORE
# 0        Massachusetts Institute of Technology (MIT)     100.0      100.0
# 1                            Imperial College London      99.6       95.0
# 2                                Stanford University     100.0       99.7
# 3                               University of Oxford     100.0       91.0
# 4                                 Harvard University     100.0      100.0
# 5                            University of Cambridge     100.0       88.6
# 6  ETH Zurich (Swiss Federal Institute of Technol...      99.7       98.8
# 7             National University of Singapore (NUS)      99.9       95.9
# 8                    UCL (University College London)      99.9       80.9
# 9       California Institute of Technology (Caltech)      98.3      100.0
# Correlation between AR SCORE and CPF SCORE:
#            AR SCORE  CPF SCORE
# AR SCORE   1.000000  -0.276003
# CPF SCORE -0.276003   1.000000

# %%
# To plot the scatter plot of the given 
plt.figure(figsize=(8, 6))
plt.scatter(scores['AR SCORE'], scores['CPF SCORE'], color='green')

for i, row in scores.iterrows():
    plt.text(row['AR SCORE'] + 0.5, row['CPF SCORE'], row['Institution Name'], fontsize=8)

plt.xlabel('AR SCORE', color='Blue')
plt.ylabel('CPF SCORE', color='Blue')
plt.title('AR SCORE vs CPF SCORE (Top 10 Universities)', color="Red")
plt.grid(True)
plt.show()

# %%
research_strength = top_10_universities[['Institution Name','2026 Rank(cleaned)', 'CPF SCORE','Research','Focus']] #to find the which university is more focused on research, high rank university also has high CPF or reseach values, also reach shows the overall contribution to the ranking.
print(research_strength.sort_values('CPF SCORE', ascending= False))
# Out:
#                                     Institution Name  2026 Rank(cleaned)  \
# 0        Massachusetts Institute of Technology (MIT)                 1.0
# 4                                 Harvard University                 5.0
# 9       California Institute of Technology (Caltech)                10.0
# 2                                Stanford University                 3.0
# 6  ETH Zurich (Swiss Federal Institute of Technol...                 7.0
# 7             National University of Singapore (NUS)                 8.0
# 1                            Imperial College London                 2.0
# 3                               University of Oxford                 4.0
# 5                            University of Cambridge                 6.0
# 8                    UCL (University College London)                 9.0
#
#    CPF SCORE Research Focus
# 0      100.0       VH    CO
# 4      100.0       VH    FC
# 9      100.0       VH    FO
# 2       99.7       VH    FC
# ...

# %%
plt.figure(figsize=(10, 6))
plt.barh(top_10_universities['Institution Name'], top_10_universities['CPF SCORE'], color='green')
plt.xlabel('CPF SCORE')
plt.title('Top 10 Universities by CPF (Citations per Faculty)')
plt.gca().invert_yaxis()
plt.show()

# %%
# Some universities have very high research
very_high_research = top_10_universities[top_10_universities['Research'] == 'VH']
print(very_high_research[['Institution Name', 'CPF SCORE', 'Research']])
# Out:
#                                     Institution Name  CPF SCORE Research
# 0        Massachusetts Institute of Technology (MIT)      100.0       VH
# 1                            Imperial College London       95.0       VH
# 2                                Stanford University       99.7       VH
# 3                               University of Oxford       91.0       VH
# 4                                 Harvard University      100.0       VH
# 5                            University of Cambridge       88.6       VH
# 6  ETH Zurich (Swiss Federal Institute of Technol...       98.8       VH
# 7             National University of Singapore (NUS)       95.9       VH
# 8                    UCL (University College London)       80.9       VH
# 9       California Institute of Technology (Caltech)      100.0       VH
